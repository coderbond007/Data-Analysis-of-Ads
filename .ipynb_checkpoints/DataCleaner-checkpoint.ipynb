# %%
import pandas

import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn

# Variable declarations
FILE_PATH = "Filtered_Data.csv"
SEPARATOR = ","
CLICK_THRESHOLD = 1000
MAX_ROWS = 500
MISCELLANEOUS = 'misc'

# imported the CSV data
dataframe = pandas.read_csv(FILE_PATH, sep = SEPARATOR)

# Drop the unused column
if 'Unnamed: 0' in dataframe.columns:
    dataframe = dataframe.drop('Unnamed: 0', axis = 1)

# Remove the same prefix from all columns names
dataframe.columns  = [ column_name.split('.')[1] for column_name in dataframe.columns ]

dataframe.head()
# Out:
#          ts impression_system_date  hour  conversion_status  cc_id_null_ind   ...    ad_market_place_id  click_click_status  kmean_category_name  partner_id version
# 0  20190106             2019-01-06     1                  1               0   ...                  1027                   1              missing   8PRHGG6T9       1
# 1  20190106             2019-01-06     1                  1               0   ...                  1027                   1              missing   8PRHGG6T9       1
# 2  20190106             2019-01-06     2                  0               0   ...                  1027                   1              missing   8PRHGG6T9       1
# 3  20190106             2019-01-06     4                  0               0   ...                  1027                   1              missing   8PRHGG6T9       1
# 4  20190106             2019-01-06     6                  0               0   ...                  1027                   1              missing   8PRHGG6T9       1
#
# [5 rows x 42 columns]

# %%
# removing all data having single values in entire columns
for column in dataframe.columns:
    if(dataframe[column].nunique() == 1):
        dataframe = dataframe.drop(column, axis = 1)

# %%
# Remove the timestamp data and impression system date data - results not dependent on the time frame
dataframe = dataframe.drop('ts', axis = 1)
dataframe = dataframe.drop('impression_system_date', axis = 1)

# Server hour do not matters
dataframe = dataframe.drop('hour', axis = 1)

# Data have only 3 values of *au* region, and conversion status 0 for all of them
dataframe = dataframe.drop('enriched_country', axis = 1)

# Data is similar to cvr_base_data_table.click_city
dataframe = dataframe.drop('impression_city', axis = 1)

# Ad-Bid is the cost which is irrespecti   ve of conversion from user side
dataframe = dataframe.drop('ad_bid', axis = 1)

# Ad CPA goal do not affects the conversion status
dataframe = dataframe.drop('ad_cpa_goal', axis = 1)

# Click Conf GMT Offset do not affects the conversion status
dataframe = dataframe.drop('click_conf_gmt_offset', axis = 1)

# Date Time do not affects and is too granuler to looku[, thus do not affects the conversion status
dataframe = dataframe.drop('click_user_datetime', axis = 1)

# Publisher Domain do not affects the conversion status
dataframe = dataframe.drop('enriched_publisher_domain', axis = 1)

# Impression ISP Name do not affects the conversion status
dataframe = dataframe.drop('impression_isp_name', axis = 1)

# below data is too granular to predict something
dataframe = dataframe.drop('ad_keyword', axis = 1)
dataframe = dataframe.drop('click_city', axis = 1)
dataframe = dataframe.drop('raw_sub_publisher_id', axis = 1)
dataframe = dataframe.drop('category_name', axis = 1)
dataframe = dataframe.drop('click_id', axis = 1)
dataframe = dataframe.drop('cc_id', axis = 1)
dataframe = dataframe.drop('raw_publisher_id', axis = 1)
dataframe = dataframe.drop('raw_sub_sub_publisher_id', axis = 1)

# %%
dataframe.head()
# Out:
#    conversion_status   ad_id  hour_of_day enriched_derived_device     ...      click_browser  raw_sync_partner_id  click_state  partner_id
# 0                  1  138154           20                  mobile     ...      google,chrome                    1           ga   8PRHGG6T9
# 1                  1  138154           20                  mobile     ...      google,chrome                    1           ga   8PRHGG6T9
# 2                  0  138154           20                  mobile     ...      google,chrome                    1           al   8PRHGG6T9
# 3                  0  138154           23                  mobile     ...      google,chrome                    1           in   8PRHGG6T9
# 4                  0  128699           22                  mobile     ...      google,chrome                    1           ca   8PRHGG6T9
#
# [5 rows x 16 columns]

# %%
# Following column names have less entries thus can be relabelled
to_label_column = ['ad_advertiser_id', 'analyzer_name', 'click_browser', 'enriched_derived_device', 'enriched_derived_os', 'raw_sync_partner_id']
total = dataframe.shape[0]
pandas.set_option('display.max_rows', MAX_ROWS)

# Function for aggregation on basis of click, conversion and CVR(conversion ratio)
fun = {'conversion_status' : {
    'conversion' : 'sum',
    'click' : 'count'
}}

# Iterate through above columns list and 'misc' the data which is too sparse to use 
# for classification or modelling
for col in to_label_column:
    dfg = dataframe.groupby(col).agg(fun).reset_index()
    dfg.columns = dfg.columns.droplevel(0)
    dfg['cvr'] = dfg['conversion'] / dfg['click']
    dfg['click percentage of total data'] = dfg['click'] / total * 100
    declareMisc = set()
    for index, row in dfg.iterrows():
        if(row['click'] >= CLICK_THRESHOLD):
            continue
        declareMisc.add(row[''])
    print (declareMisc)
    for vals in declareMisc:
        dataframe.loc[dataframe[col] == vals, col] = MISCELLANEOUS
    
    print (dataframe[col].value_counts(), '\n\n')
# Out:
# {1633.0, 1351.0}
# 1387    30042
# 1458    21280
# 1637    13763
# 1608    10848
# 1619     7491
# 1640     5422
# 1581     5397
# 1461     4666
# 1375     4468
# 1518     3869
# 1454     3199
# 1352     3192
# 1492     2985
# 1521     2000
# 1517     1890
# 1641     1500
# 1630     1478
# misc      845
# Name: ad_advertiser_id, dtype: int64
#
#
# {'broadanalyserv2', 'categoryanalyser'}
# keywordanalyserv2     104031
# nofilteranalyser        8809
# phraseanalyser          7537
# forcedanalyser          1904
# contextualanalyser      1469
# misc                     585
# Name: analyzer_name, dtype: int64
#
#
# {'blackberry,browser', 'nokia', 'ie,mobile', 'mozilla,like,unknown', 'opera,mini', 'opera', 'android,httpurlconnection', 'android,browser', 'unknown', 'chromium', 'ucbrowser', 'maxthon'}
# google,chrome        61376
# safari               25944
# edge                 16964
# internet,explorer    11315
# mozilla,firefox       3600
# applewebkit           3413
# silk                  1356
# misc                   367
# Name: click_browser, dtype: int64
#
#
# {'unknown,device'}
# mobile     59017
# desktop    58385
# tablet      6909
# misc          24
# Name: enriched_derived_device, dtype: int64
#
#
# {'linux'}
# windows       49543
# android       39203
# ios           26614
# mac            6505
# unknown,os     2074
# misc            396
# Name: enriched_derived_os, dtype: int64
#
#
# {11.0, 4.0}
# 1       115068
# 2         9251
# misc        16
# Name: raw_sync_partner_id, dtype: int64

# %%
dataframe.shape
# Out:
# (124335, 16)
